# %%
# First, mount your google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# *Once* the drive is accessible for google colab, we move inside of your google drive.

# %%
# Move to the directtory that contains our google drive, into a folder called Colab_Notebooks!
# !ls
# Out:
# drive  sample_data

# %%
cd /content/drive/MyDrive/Visualització de dades
# Out:
# /content/drive/MyDrive/Visualització de dades

# %%
# Check that we are in the correct folder
# If this is not correct you may need to create the folder mentioned above
# !pwd
# Out:
# /content/drive/MyDrive/Visualització de dades

# %%
import pandas as pd

# Llegim l'arxiu CSV
df = pd.read_csv('iris.csv')

# Elimina la columna 'species'
df = df.drop(columns=['species'])

# Calcula la matriu de correlació
correlation_matrix = df.corr()

# Veiem la matriu de correlació
print("\nMatriz de correlación:")
print(correlation_matrix)
# Out:
# Matriz de correlación:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Llegim l'arxiu CSV
df = pd.read_csv('iris.csv')

# Elimina la columna 'species'
df = df.drop(columns=['species'])

# Calcula la matriu de correlació
correlation_matrix = df.corr()

# Crea un mapa de calor per visualitzar la matriu de correlació
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriu de correlació flor Iris')
plt.show()
